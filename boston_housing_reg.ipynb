# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#export the data
df=pd.read_csv("/content/HousingData.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#to print first 5 columns of the data
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
#to print last 5 columns of the data
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
#to print the order of the data
df.shape
# Out:
# (506, 14)

# %%
#to print the type of data
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
#to print the statistical describtion of the data
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#check whether the data has any missing values
df.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
#to replace all missing values of each column with mean
df=df.fillna(df.mean())

# %%
#check the missing values
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# Data Visualization

# %%
# Determine number of observation for each value of "CHASE"
df["CHAS"].value_counts()
# Out:
# 0.000000    452
# 1.000000     34
# 0.069959     20
# Name: CHAS, dtype: int64

# %%
#Determining count in visual form using count plot
sns.countplot(x="CHAS",data=df).set_title("CHAS-wise count of data")
# Out:
# Text(0.5, 1.0, 'CHAS-wise count of data')

# %%
#creating boxplot
sns.boxplot(x="CHAS",y="AGE",data=df).set_title("Age-Chas boxplot")
# Out:
# Text(0.5, 1.0, 'Age-Chas boxplot')

# %%
#creating distribution plot of variables
plt.figure(1,figsize=(15,15))
plt.subplot(331)
sns.distplot(df["CRIM"],bins=5).set_title("Distribution of CRIM")
plt.subplot(332)
sns.distplot(df["ZN"],bins=5).set_title("Distribution of ZN")
plt.subplot(333)
sns.distplot(df["INDUS"],bins=10).set_title("Distribution of INDUS")
plt.subplot(334)
sns.distplot(df["NOX"],bins=20).set_title("Distribution of NOX")
plt.subplot(335)
sns.distplot(df["RM"],bins=20).set_title("Distribution of RM")
plt.subplot(336)
sns.distplot(df["AGE"],bins=20).set_title("Distribution of AGE")
plt.subplot(337)
sns.distplot(df["DIS"],bins=15).set_title("Distribution of DTS")
plt.subplot(338)
sns.distplot(df["TAX"],bins=15).set_title("Distribution of TAX")
plt.subplot(339)
sns.distplot(df["RAD"],bins=15).set_title("Distribution of RAD")
plt.suptitle("Distribution plot of variables")
plt.show()
# Out:
# <ipython-input-98-c288910658f3>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["CRIM"],bins=5).set_title("Distribution of CRIM")
# <ipython-input-98-c288910658f3>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#creating hostogram of variables "PTRATIO, B, LSTAT"
plt.figure(2,figsize=(15,15))
plt.subplot(131)
df["PTRATIO"].plot.hist(bins=10).set_title("Histogram of PTRATIO")
plt.subplot(132)
df["B"].plot.hist(bins=10).set_title("Histogram of B")
plt.subplot(133)
df["LSTAT"].plot.hist(bins=10).set_title("Histogram of LSTAT")
plt.suptitle("Histogram of Variables")
plt.show()

# %%
#creating a heatmap of correlations
sns.heatmap(df.corr(),annot=True,cmap="RdYlGn")
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.title("Heatmap of corelation between variables",fontsize=16)
plt.show()

# %%
#creating a scatter plot
sns.scatterplot(x="INDUS",y="RM",hue="CHAS",data=df).set_title("Scatter plot of INDUS-RM")
plt.xlabel("INDUS")
plt.ylabel('RM')
plt.show()

# %%
#scatter pair plot considering kde as diagonal plot
sns.pairplot(df[["ZN","INDUS","RM","NOX","CRIM"]],kind="scatter",diag_kind="kde")
plt.suptitle("Scatter pairplot of observations")
plt.show()

# %%
#Regression pair plot considering histogram as diagonal plot
sns.pairplot(df[["B","DIS","RAD","TAX","PTRATIO"]],diag_kind="hist",kind="reg")
plt.suptitle("Regression pairplot of observations")
plt.show()

# %%
#Determining outline by calculating z-score.
from scipy import stats
zscore=np.abs(stats.zscore(df))
zscore
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM           AGE  \
# 0    0.422328  0.296443  1.311010  0.279851  0.144217  0.413672  1.210593e-01
# 1    0.419870  0.489639  0.599771  0.279851  0.740262  0.194274  3.787156e-01
# 2    0.419872  0.489639  0.599771  0.279851  0.740262  1.282714  2.706270e-01
# 3    0.419277  0.489639  1.330435  0.279851  0.835284  1.016303  8.287698e-01
# 4    0.414981  0.489639  1.330435  0.279851  0.835284  1.228577  5.223385e-01
# ..        ...       ...       ...       ...       ...       ...           ...
# 501  0.415733  0.489639  0.126411  0.279851  0.158124  0.439316  2.121240e-02
# 502  0.417766  0.489639  0.126411  0.279851  0.158124  0.234548  2.984598e-01
# 503  0.415952  0.489639  0.126411  0.279851  0.158124  0.984960  8.201227e-01
# 504  0.410232  0.489639  0.126411  0.279851  0.158124  0.725672  7.581068e-01
# 505  0.417515  0.489639  0.126411  0.279851  0.158124  0.362767  5.184109e-16
#
# ...

# %%
#Determine the index where zscore is greater than 3
outlierlist=np.where(zscore>3)
print("The indexs of outliers is",outlierlist[0])
print("The number of outliers is",len(outlierlist[0]))
# Out:
# The indexs of outliers is [ 55  56  57  65  66 102 141 142 154 155 160 162 163 195 196 197 198 199
#  200 201 202 203 204 208 209 210 211 212 216 218 219 220 221 222 225 234
#  236 254 255 256 257 262 269 273 274 276 277 282 283 283 284 286 290 291
#  292 347 348 351 352 353 353 354 354 355 356 357 358 363 364 364 365 367
#  369 370 372 373 374 374 380 398 404 405 406 410 410 411 412 412 414 414
#  415 416 418 418 419 423 424 425 426 427 427 429 431 436 437 438 438 445
#  450 454 455 456 457 466]
# The number of outliers is 114

# %%
#removing the outliers from the dataset
df_1=df[(zscore<3).all(axis=1)]
print("Dimension after removing outliers",df_1.shape)
# Out:
# Dimension after removing outliers (403, 14)

# %%
x = df_1.iloc[:,:-1]
y = df_1.iloc[:,-1]

# %%
#split data
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_train
# Out:
#          CRIM    ZN      INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 224   0.31533   0.0   6.200000   0.0  0.504  8.266  78.3  2.8944    8  307
# 403  24.80170   0.0  18.100000   0.0  0.693  5.349  96.0  1.7028   24  666
# 309   0.34940   0.0   9.900000   0.0  0.544  5.972  76.7  3.1025    4  304
# 69    0.12816  12.5   6.070000   0.0  0.409  5.885  33.0  6.4980    4  345
# 58    0.15445  25.0   5.130000   0.0  0.453  6.145  29.2  7.8148    8  284
# ..        ...   ...        ...   ...    ...    ...   ...     ...  ...  ...
# 397   7.67202   0.0  18.100000   0.0  0.693  5.747  98.9  1.6334   24  666
# 227   0.41238   0.0   6.200000   0.0  0.504  7.163  79.9  3.2157    8  307
# 123   0.15038   0.0  11.083992   0.0  0.581  5.856  97.0  1.9444    2  188
# 47    0.22927   0.0  11.083992   0.0  0.448  6.030  85.5  5.6894    3  233
# 185   0.06047   0.0   2.460000   0.0  0.488  6.153  68.8  3.2797    3  193
#
#      PTRATIO       B  LSTAT
# 224     17.4  385.05   4.14
# ...

# %%
x_test
# Out:
# 224    44.8
# 403     8.3
# 309    20.3
# 69     20.9
# 58     23.3
#        ...
# 397     8.5
# 227    31.6
# 123    17.3
# 47     16.6
# 185    29.6
# Name: MEDV, Length: 322, dtype: float64

# %%
y_train
# Out:
#         CRIM    ZN  INDUS      CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 235  0.33045   0.0   6.20  0.000000  0.507  6.086   61.5  3.6519    8  307
# 402  9.59571   0.0  18.10  0.000000  0.693  6.404  100.0  1.6390   24  666
# 62   0.11027  25.0   5.13  0.000000  0.453  6.456   67.8  7.2255    8  284
# 83   0.03551  25.0   4.86  0.000000  0.426  6.167   46.7  5.4007    4  281
# 70   0.08826   0.0  10.81  0.000000  0.413  6.417    6.6  5.2873    4  305
# ..       ...   ...    ...       ...    ...    ...    ...     ...  ...  ...
# 20   1.25179   0.0   8.14  0.000000  0.538  5.570   98.1  3.7979    4  307
# 119  0.14476   0.0  10.01  0.069959  0.547  5.731   65.2  2.7592    6  432
# 14   0.63796   0.0   8.14  0.069959  0.538  6.096   84.5  4.4619    4  307
# 326  0.30347   0.0   7.38  0.000000  0.493  6.312   28.9  5.4159    5  287
# 317  0.24522   0.0   9.90  0.000000  0.544  5.782   71.7  4.0317    4  304
#
#      PTRATIO       B  LSTAT
# 235     17.4  376.75  10.88
# ...

# %%
y_test
# Out:
# 235    24.0
# 402    12.1
# 62     22.2
# 83     22.9
# 70     24.2
#        ...
# 20     13.6
# 119    19.3
# 14     18.2
# 326    23.0
# 317    19.8
# Name: MEDV, Length: 81, dtype: float64

# %%
if len(x_train) != len(y_train):
    # Handle the inconsistency, either by adjusting the split or addressing missing values
    # For example, you might want to re-split the data
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Now, the number of samples in x_train and y_train should match
# Proceed with model fitting
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([24.06127231, 21.92143626, 19.76292588, 14.26302241, 26.6774076 ,
#        25.4586099 , 15.96814553, 18.92795534, 21.48473016, 17.86370155,
#        16.34777919, 23.89375311, 20.81086279, 10.68232288, 25.0692631 ,
#        23.10929481, 30.7880618 , 27.34551923, 18.21821811, 23.89821233,
#        21.98174741, 22.91841118, 17.51606738, 28.85349921, 23.24580245,
#        17.82557726, 31.31670367, 20.49166654, 24.83881599, 19.19897063,
#        14.86932107, 33.10964348, 29.17571355, 19.37771225, 32.88592364,
#        20.01842279, 20.35593443,  1.32388164, 23.87633421, 19.00881741,
#        21.99111396, 17.52589208, 11.91116525, 20.92700448, 20.18420594,
#        17.47461147, 13.76162727, 16.67450166, 37.42803492, 19.12363993,
#        17.95719596, 16.58127981, 19.4951316 , 21.55776998, 21.58772434,
#        18.42444857, 21.76097021, 23.2736544 , 28.69183583, 25.18486765,
#        16.98234512, 27.07017313, 12.45861875, 36.65607679, 21.82211723,
# ...

# %%
#Equation coefficient and intercept of new model
print("Coefficient of independent variables: ")
print(list(zip(model.coef_)))
print("Intercept in the model: ", model.intercept_)
# Out:
# Coefficient of independent variables:
# [(-0.19901780354572485,), (-0.005616995098540951,), (-0.03663508071426283,), (-14.901414985982818,), (-9.66779055268597,), (5.401074016323148,), (-0.03762945781525165,), (-1.1099919392871267,), (0.23921868640358554,), (-0.010786771276424346,), (-0.8844070783070171,), (0.0042571292616979855,), (-0.333734140251358,)]
# Intercept in the model:  22.50265695102433

# %%
#Performance evaluation
df2=pd.DataFrame({"Actual_value":y_test,"Predicted_value":y_pred,"Difference":y_test-y_pred})
df2
# Out:
#      Actual_value  Predicted_value  Difference
# 75           21.4        24.061272   -2.661272
# 335          21.1        21.921436   -0.821436
# 337          18.5        19.762926   -1.262926
# 33           13.1        14.263022   -1.163022
# 42           25.3        26.677408   -1.377408
# ..            ...              ...         ...
# 45           19.3        22.295527   -2.995527
# 95           28.4        28.684412   -0.284412
# 302          26.4        28.101773   -1.701773
# 428          11.0        16.092506   -5.092506
# 493          21.8        20.524361    1.275639
#
# [81 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score
print("MAE is: ",mean_absolute_error(y_test,y_pred))
print("MAPE is: ",mean_absolute_percentage_error(y_test,y_pred))
print("MSE is :", mean_squared_error(y_test,y_pred))
print("R2 SCORE is: ",r2_score(y_test,y_pred))
# Out:
# MAE is:  2.9727022381825225
# MAPE is:  0.1391427207951253
# MSE is : 23.299932102005044
# R2 SCORE is:  0.6352858338641543
